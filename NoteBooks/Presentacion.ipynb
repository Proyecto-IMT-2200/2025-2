# %% [markdown]
# Como grupo, queremos analizar y también el responder las dudas que hemos tenido en el proceso
# y resultados respecto a la equidad con el tema del acceso a la educación superior chilena
# Buscamos examinar la relación entre la equidad y los procesos de admisión universitaria en Chile,
# enfocándonos en las diferencias entre comunas y grupos socioeconómicos. Utilizando datos
# disponibles desde el año 2004 hasta la actualidad respecto a los procesos de admisión PAES, PSU y
# PTU, de manera que, como objetivo tenemos comprender como influyen diversos factores como la
# residencia, estrato socioeconómico y la institución del ingreso de los puntajes.
# Esto todos los datos utilizados fueron extraidos de https://portal-transparencia.demre.cl/portal-base-datos la pagina oficial del demre que publica sus datos.

# %% [markdown]
# ### Recoleccion de datos
#  Se descargaron los Datos de forma manual a partir del siguiente link [https://portal-transparencia.demre.cl/portal-base-datos], descargados desde la Pagina oficial del demre, a traves de esto se hizo esta carpeta[[https://uccl0-my.sharepoint.com/:f:/g/personal/sebastin_mena_estudiante_uc_cl/EhgUUbAemNVLubCEjJvLvMkBOtbi40OF61aDvJpW7fV5DA?e=ymSFkT]] para una descarga facil de los datos, respecto a la ruta para la visualizacion de los datos se encuentran en el github, sin embargo la ruta a presentar es la siguiete :
# ```
# 2025-2/
# |_ NoteBooks/
# |  |--Graficos-Imagenes/
# |  |--|[en graficos-imagenes se contienen los datos usados para la presentacion]
# |  |--pkl-data/ [datos peakle]
# |  |--raw_data/ datos_crudos
# |  |--pregunta1.ipynb
# |  |--pregunta2.ipynb
# |  |--pregunta3.ipynb
# |  |--pregunta4.ipynb
# |  |--pregunta5.ipynb
# |  |--Modelo_Predictivo_NEM _ff.ipynb
# |  |--Lectura_Archivos.ipynb
# |  |--presentacion.ipynb
# |_ .gitignore
# |_ Prototipos/
# |__Borrador_Proyecto.ipynb
# |__Borrador_trabajo_final_seba.ipynb
# |_ requirements.txt
# |_ README.md
# ```
#
# URL (Universal Resource Locator): Los programas pueden pedir la información directa al DIR donde se guarda en el servidor. Problemas: costes altos al servidor, si cambia la localización del archivo la URL falla, riesgo de seguridad al dejar la URL o bases de datos abiertas.
#
# API (Application Programming Interface): Es más utilizado para conectar 2 tipos de programas como el front end con el back end, o distintos programas que no tengan nada que ver, solicitando datos o procesos entre sí. Es altamente utilizado.
#
# Web Scraping: Descarga el código de la página web con los datos, mediante un escaneo de la página.
#
# Muchas veces no podemos elegir el proceso, sino que debemos adaptarnos a las prácticas del servidor donde se guardan los datos. En nuestro caso, al querer evaluar datos del DEMRE, vimos que la opción más sencilla fue la descarga manual, la cual no la describí anteriormente porque es solamente hacer clic en el enlace o botón que dice “Descargar datos”, no es nada técnico ni muy avanzado. Luego los recopilamos en la misma carpeta y los subimos a nuestro OneDrive para que puedan descargarlo, pero igualmente pueden ir y descargar los datos manualmente, para tener certeza de lo que trabajamos.

# %% [markdown]
# ## Un poco de contexto
#
# a lo largo de los años nuestro pais a presetado varias pruebas de ingreso a la educacion superior(universidad/instituto/tecnico) estas pruebas son la PSU[2003 - 2020] , la PTU[2021 - 2022] y la PAES[2022 - Actualidad] estas pruebas son la encargadas de filtrar que estudiante estudiara y cual no, por medio de un porcentaje que busca medir el nivel de nuestros alumnos y jovenes en nuestro pais, en este contexto se tomo la decision como grupo de hacer un analisis por medio de la ciencia de datos [y que se puede ver en mas detalle a lo largo de lo hecho en la carpeta NoteBooks] enmfocado en responder 5 preguntas principales
#
# - 1°¿Cuantas personas se incribieron en cada periodo de admision entre 2004 a 2025?
#
# - 2°¿Hubo un aumento en las inscripciones en los periodos de transicion (PSU/PTU/PAES)?
#
# - 3°Segun el gruposocioeconomico , ¿cual fue el porcentaje de ingresos a la educacion superior?
#
# - 4°¿Que comunas presentaron los mayores porcentajes de ingresos a la educacion superior?
#
# - 5°¿Que relacion existe entre la situacion de egreso de los estudiantes y los resultados de admision a la educacion superior?

# %% [markdown]
# ## Pregunta 1
# ### ¿Cuantas personas se inscribieron en cada periodo de admision entre 2004 a 2025?
#
# Por la naturaleza de esta pregunta tomamos la decision de mostrarlo en forma de grafico explicando uno por uno que representa para mayor comprension de la informacion

# %%
from IPython.display import Image, display
import pandas as pd
import os
display(Image(filename='graficos-imagenes/pregunta1.png'))

# %% [markdown]
# ### Pero ¿Que estamos viendo con este grafico?
#
#  Aqui en el grafico, podemos ver la cantidad de gente que ha rendido la prueba de admision, a lo largo de los años.
#  Logramos identificar claramente la cantidad de inscripcion por años, siendo el punto mas alto, el año actual 2025, con mas de 300.000 personas que rindieron el examen.
#
# Observaciones Importantes:
#
# 2010 to 2014, un claro descenso de la curva ascendente que teniamos los años pasadoso. Nuestra hipotesis mas logica es el terremoto del 2010 ocurrido en febrero, debio haber afectado claramente. Pero no solo las rendiciones de ese mismo año, sino una persecucion para los años siguentes. Mas adelante veremos este suceso a mas detalla, ya que, es algo que no teniamos previsto ver.
#
#  Luego el descenso del 2020 to 2021, claramente fue efecto de la cuarentena, no profundizaremos, todos sabemos como nos afecto en el cambio de eduacion remoto y que nos afecto a todos, en todo ambito. Es la caida mas grande de todo el grafico, auqnue 3-4 años despues, nos recuperamos y volvimos a la misma taza de crecimiento.
#
# Conclusion final:
#         Las incripciones de cada años ha ido en amuento, solo por causa externas, catastrofes medioambientales y globales(virus) han afectados nuestra curva de crecimiento en la cantidad de rendicion de pruebas para la educacion Chilena
#
#
# #### SI se preguntas por los datos exactos, aqui se presentan
# ###   Datos exactos
# #### Año -- Inscritos
# ##### 2004: 153982
# ##### 2005: 169888
# ##### 2006: 176778
# ##### 2007: 212889
# ##### 2008: 218261
# ##### 2009: 243809
# ##### 2010: 253236
# ##### 2011: 252402
# ##### 2012: 242661
# ##### 2013: 244707
# ##### 2014: 243596
# ##### 2015: 257852
# ##### 2016: 266494
# ##### 2017: 269351
# ##### 2018: 274498
# ##### 2019: 278287
# ##### 2020: 292091
# ##### 2021: 238818
# ##### 2022: 254191
# ##### 2023: 293865
# ##### 2024: 306497
# ##### 2025: 311084

# %% [markdown]
# ## Pregunta 2
#
# UN recordatorio, la pregunta anterior es
# ### ¿Hubo un aumento en las inscripciones en los periodos de transicion (PSU/PTU/PAES)?
#
# La respuesta es, depende, depende de los años y el periodo en el cual estemos para con nuestra historia, por ejemplo

# %%
display(Image(filename='graficos-imagenes/pregunta2psu.png'))

# %% [markdown]
# ### ¿Que podemos notar del grafico?
#
# En el grafico podemos notar una tendencia alsista, hasta la decada del 2010, este es un gran ejemplo de lo que me refiero con "depende" , al haber una crisis en nuestro pais por la culpa del temblor del ya mencionado año, menos gente fue a educarse, y es por esto que en ese año y años superiores hubo una bajada en la rendicion de esta prueba para la educacion.

# %%
display(Image(filename='graficos-imagenes/pregunta2ptu.png'))

# %% [markdown]
# ### Que podemos notar en el grafico para la PTU?
# Podemos notar un grafico muy alzista, primero, al ser pocos años las diferencias entre las mismas se notaran "mas grandes" an lo haber comparaciones relativas, pero tambien se puede notar el aumento por el deseo de estudiar por los el cambio entre el año 2021(salir de una pandemia) al año 2922(ya estar en un mejor estado post pandemia)

# %%
display(Image(filename='graficos-imagenes/pregunta2paes.png'))

# %% [markdown]
# ### Que podemos notar en el grafico de la PAES?
#
# Podemos notar que, al igual que el grafico de la paes, peca en que al no poseer una gran cantidad de datos, la diferencia relativa se ve mas grande, sin embargo, se ve una tendencia a la alta , con una leve "caida" en la tendencia posterior al año 2024

# %% [markdown]
# ## Pregunta 3
#
# ### Segun el gruposocioeconomico , ¿cual fue el porcentaje de ingresos a la educacion superior?

# %% [markdown]
# para esta respuesta se tomo los percentiles respectivos a cada dato, se transformo en cada distribucion socioeconomica, buscando ver como es la distribucion de los grupos socioeconomicos de las respectivas universidades a lo largo del pais

# %%
display(Image(filename='graficos-imagenes/pregunta3.png'))

# %% [markdown]
# El gráfico revela una fuerte estratificación socioeconómica del sistema universitario chileno. Las universidades más selectivas y de mayor prestigio concentran una mayor proporción de estudiantes AB–C, mientras que la mayoría de las instituciones presenta perfiles mayoritariamente E. Esta estructura se mantiene estable en la serie 2004–2025, mostrando que el acceso universitario sigue estando fuertemente asociado a los ingresos del grupo familiar.

# %% [markdown]
# ## Pregunta 4
#
# ### ¿que decia la pregunta 4? , la pregunta 4 es ¿Que comunas presentaron los mayores porcentajes de ingresos a la educacion superior?
#
# En este contexto La respuesta a nuestra pregunta se puede ver en en el siguiente grafico

# %%
display(Image(filename='graficos-imagenes/tendencia_egresados_pregunta4.png'))

# %% [markdown]
# Se esta forma notando que la columna que historicamente a sido la que posee mas egresados es la comuna de santiago, seguida de maipu y temuco, de todas formas, como un top 10 general a lo largo de estos años se tiene a:

# %%
datos = pd.read_csv(os.path.join("csv_respaldo", 'Resultados_años_comuna_preg4.csv'))
datos.sort_values(ascending = False ,by = "Porcentaje").head(10)
# Out:
#     CODIGO_COMUNA NOMBRE_COMUNA  Cantidad  Porcentaje   Año
# 0         13101.0      SANTIAGO      5509       5.441  2018
# 10        13101.0      SANTIAGO      5282       5.090  2019
# 20        13101.0      SANTIAGO      4926       5.027  2020
# 30        13101.0      SANTIAGO      4452       4.824  2021
# 40        13101.0      SANTIAGO      4452       4.640  2022
# 50        13101.0      SANTIAGO      4799       4.312  2023
# 60        13101.0      SANTIAGO      4814       4.067  2024
# 21        13119.0         MAIPU      3252       3.319  2020
# 11        13119.0         MAIPU      3364       3.242  2019
# 22         9101.0        TEMUCO      3165       3.230  2020

# %% [markdown]
# Cosa curiosa, se puede ver de esta forma que claramente santiago es la mayor a lo largo de los años, al igual que se puede ver que las demas ocmunas van "tomando terreno" a medida que este porcentaje baja, esto puede tener muchas explicaciones, como gente que se va a vivir en otras comunas distintas de santiago, como sensillamente un mayor apoyo hacia otras comunas

# %% [markdown]
# ### Pregunta 5
#
# ### ¿Que relacion existe entre la situacion de egreso de los estudiantes y los resultados de admision a la educacion superior?

# %%
display(Image(filename='graficos-imagenes/pregunta5.png'))

# %% [markdown]
# ### Hallazgos principales
#
# los Hallasgos principales que notamos analizando el grafico y la informacion dada son:
# - Mayor tasa de matrícula: 25.8% (Situación: 7)
# - Menor tasa de matrícula: 2.2% (Situación: 4)
# - Puntaje promedio más alto: 667.0 (Situación: 3)
#
# ### Correlaciones
# Respecto al porcentaje de correlacion con los datos son:
#
# - Correlación años desde egreso vs tasa de matrícula: 0.161
# - Correlación años desde egreso vs puntaje promedio: -0.042
#
# ### CONCLUSIÓN:
# La relación entre situación de egreso y resultados de admisión muestra que los recién egresados (0 años) tienen mejores resultados tanto en tasas de matrícula como en puntajes, a su vez existe una tendencia descendente en ambos indicadores a medida que aumentan los años desde el egreso. La brecha más significativa se observa entre recién egresados y quienes llevan más tiempo fuera del sistema escolar, los datos sugieren que el tiempo transcurrido desde el egreso tiene un impacto negativo en las oportunidades de acceso a la educación superior

# %% [markdown]
# ## BONUS
# ### Como bonus en la elaboracion de este proyecto nos surgio la duda ¿Qué grupo socioeconómico resultó más afectado por el terremoto del 2010?
#
# es por eso que deseamos darle la respuesta a esta duda

# %%
display(Image(filename='graficos-imagenes/terremoto2010.png'))

# %% [markdown]
# A partir del grafico podemos notar que dependiendo del grupo de dependencia de cada año , siendo grupo de dependencia el tipo de establecimiento en el cual egreso el estudiante
#
# - 1.Particular pagado
# - 2.Particular subvencionado
# - 3.Municipal
#
# Se tiene un resultado distinto en como le fue en la prueba, especialmente entre el 2010 a 2011, cosa que sospechamos que es por el terremoto sucedido a inicio de decada

# %% [markdown]
# ### Creacion de modelo de ML
#
# ## Como se hizo el modelo predictivo
#
# De partida, se creo un modelo predictivo regresivo el cual busca el presentar una herramienta que predisca por medio de los datos del puntaje promedio del puntaje paes el posible puntaje nem que sacara una persona
# esto como una herramienta que predisca a la ciudadania el tener una idea de los puntajes que se sacara y el como le ira en la paes a lo largo de los datos
#
# si bien la documentacion como tal se encuentra en la seccion de Modelo_predictivo contenida en la carpeta notebooks, aqui se hara tambien un resumen de como fue la creacion/entrenamiento del modelo
#
# de partida se hizo una limpieza de los datos, de la forma mas eficiente posible seleccionando las variables necesarias , para una posterior elimninacion de los outliers
#
# Luego de esto se hizo una preparacion de los modelos, tomando como nuestra variable x , la paes de matematica y lenguaje, y como nuestra variable y el puntaje paes en correlacion a lo que buscabamos predecir
#
# posterior a eso se hizo una prediccion con varios tipos tanto regrecion lineal como polinomica
# en caso de duda se invita a ver la seccion de Modelo_predictivo pero aca se da un leve resumen

# %%
display(Image(filename='graficos-imagenes/regresion_lineal_multiple.png'))

# %% [markdown]
# ### Aqui se ve tanto la dispercion de los datos y como le fue al modelo
#
# Respecto a como les fue a los modelos, en terminos estadisticos estos son los resultados en grado 2 y grado 3
#
# === Regresión Polinomial (Grado 2) ===
# Features generados: 5
# R² (train): 0.2697
# R² (test): 0.2724
# MSE: 14060.5262
# RMSE: 118.5771
# MAE: 96.1683
#
# === Regresión Polinomial (Grado 3) ===
# Features generados: 9
# R² (train): 0.2714
# R² (test): 0.2735
# MSE: 14039.8142
# RMSE: 118.4897
# MAE: 96.0576

# %%
display(Image(filename='graficos-imagenes/regresion_polinomial.png'))

# %% [markdown]
# ### Como una comparacion general de los modelos con mejor entrenamiento aqui se ve un grafico del mismo

# %%
display(Image(filename='graficos-imagenes/Comparacion_modelos.png'))

# %% [markdown]
# ### En nuestros resultados de testeo, se vio que el mejor modelo es el de grado polinomial 3

# %%
display(Image(filename='graficos-imagenes/estadisticas_residuos.png'))

# %% [markdown]
# ### por medio de nuestro entrenamiento obtuvimos los siguientes resultados, a partir de estos datos de ejemplo
# === PREDICCIONES DE EJEMPLO ===
# Usando modelo: Polinomial Grado 3
#
# MATE1    CLEC     Prom nem     → Puntaje paes Predicho
# ============================================================
# 400      400      400.0        → 624.70
# 500      500      500.0        → 649.37
# 600      600      600.0        → 701.81
# 700      700      700.0        → 767.27
# 800      800      800.0        → 831.03
# 600      700      650.0        → 726.66
# 700      600      650.0        → 740.00
