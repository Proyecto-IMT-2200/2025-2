# %% [markdown]
# ## ¿Cuántas personas se inscribieron en cada periodo de admisión entre 2004 y 2025?

# %% [markdown]
# ### Librerias
#
#     Utilizamos pickle para la apertura optima del data frame guardado y limpiado anteriormente. Matploit para la graficacion de los datos.

# %%
import pickle
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ### Load Dataframe
#     Se carga los datos en la variable adm(admision).

# %%
with open('pkl-data/adm_lista.pkl', 'rb') as lectura:
    adm = pickle.load(lectura)

# %% [markdown]
# ### Codigo

# %%
tmp =[]
for x in range(len(adm)):
    tmp.append(int(adm[x].shape[0]))
print(tmp)
# Out:
# [153982, 169888, 176778, 212889, 218261, 243809, 253236, 252402, 242661, 244707, 243596, 257852, 266494, 269351, 274498, 278287, 292091, 238818, 254191, 293865, 306497, 311084]

# %% [markdown]
# #### Explicación
#     Al ser la primera pregunta, realizamos un codigo sencillo y eficiente, para dar el inicio a nuestro trabajo de investigacion.
#
#     Se recorre la lista, la cual tiene los data frame, y luego se crea la lista tmp(temporal), donde guardo la cantidad de filas, que alfinal son las entradas o cantidad de gente que rindo la prueba cada año. Al tener la lista, grafico los numeros de ella.

# %%
#tmp = [153982, 169888, 176778, 212889, 218261,
#       243809, 253236, 252402, 242661, 244707,
#       243596, 257852,266494, 269351, 274498,
#       278287, 292091,238818, 254191, 293865,
#       306497, 311084]

years = list(range(2004, 2026))


plt.figure(figsize=(20, 10))
plt.plot(years, tmp, marker='o', linestyle='-', color='b')
plt.title('Valores por años 2004-2025', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Cantidad de gente que rindio la prueba', fontsize=12)
plt.xticks(years, rotation=45)
plt.grid(True)
plt.tight_layout()
ruta = os.path.join("graficos-imagenes")
plt.savefig(os.path.join(ruta, 'pregunta1.png'))# guardamos el grafico en su carpeta correspondiente

plt.show()

# %% [markdown]
#     - Aqui en el grafico, podemos ver la cantidad de gente que ha rendido la prueba de admision, a lo largo de los años.
#     - Logramos identificar claramente la cantidad de inscripcion por años, siendo el punto mas alto, el año actual 2025, con mas de 300.000 personas que rindieron el examen.
#
#
#     Observaciones Importantes:
#
#         -2010 to 2014, un claro descenso de la curva ascendente que teniamos los años pasadoso. Nuestra hipotesis mas logica es el terremoto del 2010 ocurrido en febrero, debio haber afectado claramente. Pero no solo las rendiciones de ese mismo año, sino una persecucion para los años siguentes. Mas adelante veremos este suceso a mas detalla, ya que, es algo que no teniamos previsto ver.
#
#         - Luego el descenso del 2020 to 2021, claramente fue efecto de la cuarentena, no profundizaremos, todos sabemos como nos afecto en el cambio de eduacion remoto y que nos afecto a todos, en todo ambito. Es la caida mas grande de todo el grafico, auqnue 3-4 años despues, nos recuperamos y volvimos a la misma taza de crecimiento.
#
#     - Conclusion final:
#         Las incripciones de cada años ha ido en amuento, solo por causa externas, catastrofes medioambientales y globales(virus) han afectados nuestra curva de crecimiento en la cantidad de rendicion de pruebas para la educacion Chilena
#
#
#
# #
# ###   Datos exactos
# #### Año -- Inscritos
# ##### 2004: 153982
# ##### 2005: 169888
# ##### 2006: 176778
# ##### 2007: 212889
# ##### 2008: 218261
# ##### 2009: 243809
# ##### 2010: 253236
# ##### 2011: 252402
# ##### 2012: 242661
# ##### 2013: 244707
# ##### 2014: 243596
# ##### 2015: 257852
# ##### 2016: 266494
# ##### 2017: 269351
# ##### 2018: 274498
# ##### 2019: 278287
# ##### 2020: 292091
# ##### 2021: 238818
# ##### 2022: 254191
# ##### 2023: 293865
# ##### 2024: 306497
# ##### 2025: 311084
